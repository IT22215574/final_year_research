# %% [markdown]
# # Model training
# This notebook runs the training pipeline from backend/model_train.py
#
# Cell 2 runs the training function which will read dataset, train model and save it.

# %%
from backend.model_train import train_and_save

train_and_save()
